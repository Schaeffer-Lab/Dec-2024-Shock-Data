# %%
import numpy as np
import matplotlib.pyplot as plt
V_list = []
N = 100
theta_max = 0.125*(np.pi)
for i in range(0,N):
    if i == 0:
        theta = 0
        phi = 0
    else:
        theta = np.arccos(i/N)
    phi = i
    V_i = [np.cos(theta),theta*np.sin(phi),theta*np.cos(phi)]
    V_list.append(V_i)
    plt.scatter(V_i[2],V_i[1])
